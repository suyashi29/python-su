# %% [markdown]
# ## RNN is used to generate a sequence of text, such as generating text character by character.
#
# - A simple Recurrent Neural Network (RNN) can be used for text data sequence generation in various ways. Here are a few examples:
#
# ## Character-level Text Generation:
#
# ### Generate text character by character.
# Example: Predict the next character in a sequence based on previous characters.
# - Application: Generating new text in the style of a given text corpus (e.g., generating new Shakespearean text).
# Word-level Text Generation:
#
# #### Generate text word by word.
# Example: Predict the next word in a sequence based on previous words.
# - Application: Creating coherent sentences or paragraphs based on a training corpus (e.g., generating news headlines).

# %% [markdown]
# ### Example 1: Predicting the Next Character in a String

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from tensorflow.keras.utils import to_categorical

# Generate a sequence of characters
alphabet = "abcdefghijklmnopqrstuvwxyz"
sequence_length = len(alphabet)

# Prepare data
X = []
y = []
for i in range(sequence_length - 4):
    X.append([ord(char) for char in alphabet[i:i+4]])
    y.append(ord(alphabet[i+4]))

X = np.array(X).reshape((-1, 4, 1)) / 255.0  # Normalize
y = to_categorical(y, num_classes=256)  # One-hot encoding#

# %%
# Define RNN model
model = Sequential()
model.add(SimpleRNN(50, activation='relu', input_shape=(4, 1)))
model.add(Dense(256, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy')

# Train the model
model.fit(X, y, epochs=1000, verbose=0)

# %%
# Generate a new sequence
input_sequence = np.array([ord(char) for char in "bcde"]).reshape((1, 4, 1)) / 255.0
prediction = model.predict(input_sequence, verbose=0)
predicted_char = chr(np.argmax(prediction))

# %%
input_sequence
# Out:
# array([[[0.38039216],
#         [0.38431373],
#         [0.38823529],
#         [0.39215686]]])

# %%
# Print results
print("Input Sequence:", "bcde")
print("Next Character Prediction:", predicted_char)
# Out:
# Input Sequence: bcde
# Next Character Prediction: e

# %% [markdown]
# ### Example 2: Generate text word by word

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# Example input text
text = "how are you feeling today"

# Create character mapping
chars = sorted(set(text))
char_to_idx = {ch: idx for idx, ch in enumerate(chars)}
idx_to_char = {idx: ch for idx, ch in enumerate(chars)}
num_chars = len(chars)

# Prepare input-output pairs for training
max_len = 10  # Adjust max_len based on the sequences used for training
step = 1
sequences = []
next_chars = []
for i in range(0, len(text) - max_len, step):
    sequences.append(text[i:i + max_len])
    next_chars.append(text[i + max_len])
    
# Vectorization
X = np.zeros((len(sequences), max_len, num_chars), dtype=np.float32)
y = np.zeros((len(sequences), num_chars), dtype=np.float32)
for i, sequence in enumerate(sequences):
    for t, char in enumerate(sequence):
        X[i, t, char_to_idx[char]] = 1.0
    y[i, char_to_idx[next_chars[i]]] = 1.0

# Build the RNN model
model = Sequential()
model.add(LSTM(128, input_shape=(max_len, num_chars)))
model.add(Dense(num_chars, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

# Training the model
model.fit(X, y, batch_size=1, epochs=100, verbose=2)

# Function to generate text
def generate_text(model, seed_text, max_len, num_chars):
    generated_text = seed_text
    for _ in range(max_len):
        x_pred = np.zeros((1, max_len, num_chars), dtype=np.float32)
        for t, char in enumerate(seed_text):
            x_pred[0, t, char_to_idx[char]] = 1.0
        preds = model.predict(x_pred, verbose=0)[0]
        next_index = np.random.choice(num_chars, p=preds)
        next_char = idx_to_char[next_index]
        generated_text += next_char
        seed_text = seed_text[1:] + next_char
    return generated_text

# Generate a sequence
generated_sequence = generate_text(model, seed_text="hello ", max_len=10, num_chars=num_chars)  # Use max_len consistent with training
print("Generated Sequence:")
print(generated_sequence)
# Out:
# Epoch 1/100
# 16/16 - 3s - 206ms/step - loss: 2.8422
# Epoch 2/100
# 16/16 - 0s - 10ms/step - loss: 2.7606
# Epoch 3/100
# 16/16 - 0s - 10ms/step - loss: 2.6861
# Epoch 4/100
# 16/16 - 0s - 11ms/step - loss: 2.5583
# Epoch 5/100
# 16/16 - 0s - 8ms/step - loss: 2.2718
# Epoch 6/100
# 16/16 - 0s - 7ms/step - loss: 1.9581
# Epoch 7/100
# 16/16 - 0s - 8ms/step - loss: 1.7262
# Epoch 8/100
# 16/16 - 0s - 7ms/step - loss: 1.4023
# Epoch 9/100
# 16/16 - 0s - 11ms/step - loss: 1.4496
# Epoch 10/100
# 16/16 - 0s - 8ms/step - loss: 1.2031
# Epoch 11/100
# 16/16 - 0s - 11ms/step - loss: 0.9704
# Epoch 12/100
# 16/16 - 0s - 12ms/step - loss: 0.8550
# Epoch 13/100
# 16/16 - 0s - 9ms/step - loss: 0.7398
# Epoch 14/100
# 16/16 - 0s - 9ms/step - loss: 0.6518
# Epoch 15/100
# 16/16 - 0s - 9ms/step - loss: 0.5988
# Epoch 16/100
# 16/16 - 0s - 11ms/step - loss: 0.6312
# Epoch 17/100
# 16/16 - 0s - 12ms/step - loss: 0.6329
# Epoch 18/100
# 16/16 - 0s - 10ms/step - loss: 0.6956
# Epoch 19/100
# 16/16 - 0s - 10ms/step - loss: 0.4630
# Epoch 20/100
# 16/16 - 0s - 13ms/step - loss: 0.3798
# Epoch 21/100
# 16/16 - 0s - 9ms/step - loss: 0.2531
# Epoch 22/100
# 16/16 - 0s - 7ms/step - loss: 0.2196
# Epoch 23/100
# 16/16 - 0s - 7ms/step - loss: 0.1741
# Epoch 24/100
# 16/16 - 0s - 10ms/step - loss: 0.1463
# Epoch 25/100
# 16/16 - 0s - 11ms/step - loss: 0.1325
# Epoch 26/100
# 16/16 - 0s - 10ms/step - loss: 0.1194
# Epoch 27/100
# 16/16 - 0s - 11ms/step - loss: 0.1051
# Epoch 28/100
# 16/16 - 0s - 9ms/step - loss: 0.0979
# Epoch 29/100
# 16/16 - 0s - 8ms/step - loss: 0.0895
# Epoch 30/100
# 16/16 - 0s - 8ms/step - loss: 0.0819
# Epoch 31/100
# 16/16 - 0s - 10ms/step - loss: 0.0737
# Epoch 32/100
# 16/16 - 0s - 11ms/step - loss: 0.0668
# Epoch 33/100
# 16/16 - 0s - 10ms/step - loss: 0.0629
# Epoch 34/100
# 16/16 - 0s - 11ms/step - loss: 0.0565
# Epoch 35/100
# 16/16 - 0s - 12ms/step - loss: 0.0548
# Epoch 36/100
# 16/16 - 0s - 11ms/step - loss: 0.0501
# Epoch 77/100
# 16/16 - 0s - 11ms/step - loss: 0.0087
# Epoch 78/100
# 16/16 - 0s - 10ms/step - loss: 0.0085
# Epoch 79/100
# 16/16 - 0s - 8ms/step - loss: 0.0082
# Epoch 80/100
# 16/16 - 0s - 11ms/step - loss: 0.0080
# Epoch 81/100
# 16/16 - 0s - 10ms/step - loss: 0.0078
# Epoch 82/100
# 16/16 - 0s - 9ms/step - loss: 0.0076
# Epoch 83/100
# 16/16 - 0s - 10ms/step - loss: 0.0074
# Epoch 84/100
# 16/16 - 0s - 10ms/step - loss: 0.0072
# Epoch 85/100
# 16/16 - 0s - 10ms/step - loss: 0.0070
# Epoch 86/100
# 16/16 - 0s - 10ms/step - loss: 0.0068
# Epoch 87/100
# 16/16 - 0s - 9ms/step - loss: 0.0066
# Epoch 88/100
# 16/16 - 0s - 10ms/step - loss: 0.0065
# Epoch 89/100
# 16/16 - 0s - 9ms/step - loss: 0.0063
# Epoch 90/100
# 16/16 - 0s - 10ms/step - loss: 0.0062
# Epoch 91/100
# 16/16 - 0s - 10ms/step - loss: 0.0060
# Epoch 92/100
# 16/16 - 0s - 10ms/step - loss: 0.0059
# Epoch 93/100
# 16/16 - 0s - 11ms/step - loss: 0.0057
# Epoch 94/100
# 16/16 - 0s - 10ms/step - loss: 0.0056
# Epoch 95/100
# 16/16 - 0s - 11ms/step - loss: 0.0055
# Epoch 96/100
# 16/16 - 0s - 10ms/step - loss: 0.0054
# Epoch 97/100
# 16/16 - 0s - 12ms/step - loss: 0.0052
# Epoch 98/100
# 16/16 - 0s - 22ms/step - loss: 0.0051
# Epoch 99/100
# 16/16 - 0s - 10ms/step - loss: 0.0050
# Epoch 100/100
# 16/16 - 0s - 7ms/step - loss: 0.0049
# Generated Sequence:
# hello ?y?fgnity?

# %% [markdown]
# ## 3.Example Word sequence Generation

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Example text data (replace with your dataset)
text_data = [
    "Hi what are you doing today? Any plans more input output will improve"
]

# Tokenize the text data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_data)
total_words = len(tokenizer.word_index) + 1

# Create input sequences using tokenizer
input_sequences = []
for line in text_data:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# Pad sequences for equal length input
max_sequence_len = max([len(seq) for seq in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# Create predictors and labels
predictors, label = input_sequences[:,:-1],input_sequences[:,-1]

# Convert labels to categorical one-hot encoding
label = tf.keras.utils.to_categorical(label, num_classes=total_words)

# Build the model
model = Sequential()
model.add(Embedding(total_words, 10, input_length=max_sequence_len-1))
model.add(LSTM(50))
model.add(Dense(total_words, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(predictors, label, epochs=100, verbose=1)

# Function to generate text
def generate_text(seed_text, next_words, model, max_sequence_len):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted_probs = model.predict(token_list, verbose=0)[0]
        predicted_index = np.argmax(predicted_probs)
        
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted_index:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

# Generate text
generated_text = generate_text("Hi Rubi", 5, model, max_sequence_len)
print(generated_text)
# Out:
# Epoch 1/100
# C:\Users\Suyashi144893\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.0000e+00 - loss: 2.6393
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.0833 - loss: 2.6371
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.0833 - loss: 2.6348
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.0833 - loss: 2.6324
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0833 - loss: 2.6300
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1667 - loss: 2.6275
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.1667 - loss: 2.6249
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1667 - loss: 2.6221
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.1667 - loss: 2.6191
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2500 - loss: 2.6160
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2500 - loss: 2.6125
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2500 - loss: 2.6088
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2500 - loss: 2.6048
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.2500 - loss: 2.6004
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2500 - loss: 2.5955
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.1667 - loss: 2.5902
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1667 - loss: 2.5843
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.1667 - loss: 2.5777
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.1667 - loss: 2.5704
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1667 - loss: 2.5622
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.1667 - loss: 2.5531
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0833 - loss: 2.5429
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.0833 - loss: 2.5315
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.0833 - loss: 2.5187
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.0833 - loss: 2.5044
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.0833 - loss: 2.4885
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.0833 - loss: 2.4709
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.0833 - loss: 2.4516
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.0833 - loss: 2.4308
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.0833 - loss: 2.4088
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.0833 - loss: 2.3856
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.1667 - loss: 2.3611
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.1667 - loss: 2.3350
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.2500 - loss: 2.3066
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.1667 - loss: 2.2754
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.0000e+00 - loss: 2.2414
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.1667 - loss: 2.2053
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1667 - loss: 2.1678
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.1667 - loss: 2.1294
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.2500 - loss: 2.0895
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.2500 - loss: 2.0479
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.3333 - loss: 2.0058
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.2500 - loss: 1.9653
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.2500 - loss: 1.9272
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.2500 - loss: 1.8894
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.2500 - loss: 1.8516
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3333 - loss: 1.8165
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.3333 - loss: 1.7839
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3333 - loss: 1.7506
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4167 - loss: 1.7194
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4167 - loss: 1.6891
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5000 - loss: 1.6576
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5000 - loss: 1.6288
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5000 - loss: 1.5981
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.5000 - loss: 1.5704
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5000 - loss: 1.5411
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.5833 - loss: 1.5148
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5000 - loss: 1.4876
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5833 - loss: 1.4611
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5833 - loss: 1.4365
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5000 - loss: 1.4109
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5833 - loss: 1.3855
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5833 - loss: 1.3623
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5833 - loss: 1.3406
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5833 - loss: 1.3176
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7500 - loss: 1.2943
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6667 - loss: 1.2715
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7500 - loss: 1.2506
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7500 - loss: 1.2318
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9167 - loss: 1.2155
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7500 - loss: 1.2039
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9167 - loss: 1.1774
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9167 - loss: 1.1561
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8333 - loss: 1.1446
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9167 - loss: 1.1284
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8333 - loss: 1.1094
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8333 - loss: 1.0910
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8333 - loss: 1.0794
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.7500 - loss: 1.0712
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8333 - loss: 1.0496
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9167 - loss: 1.0311
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8333 - loss: 1.0178
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8333 - loss: 1.0080
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7500 - loss: 1.0035
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8333 - loss: 0.9825
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8333 - loss: 0.9646
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9167 - loss: 0.9497
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9167 - loss: 0.9405
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8333 - loss: 0.9373
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8333 - loss: 0.9261
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.7500 - loss: 0.9183
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9167 - loss: 0.8938
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9167 - loss: 0.8825
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8333 - loss: 0.8825
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8333 - loss: 0.8717
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8333 - loss: 0.8613
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9167 - loss: 0.8413
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9167 - loss: 0.8336
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8333 - loss: 0.8357
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9167 - loss: 0.8222
# Hi Rubi what what what doing today

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Example text data (replace with your dataset)
text_data = [
    "Sana and Esha Love to watch disney movies .",
    "She sells seashells by the seashore.",
    "How much wood would a woodchuck chuck if a woodchuck could chuck wood?"
]

# Tokenize the text data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_data)
total_words = len(tokenizer.word_index) + 1

# Create input sequences using tokenizer
input_sequences = []
for line in text_data:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# Pad sequences for equal length input
max_sequence_len = max([len(seq) for seq in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# Create predictors and labels
predictors, label = input_sequences[:,:-1],input_sequences[:,-1]

# Convert labels to categorical one-hot encoding
label = tf.keras.utils.to_categorical(label, num_classes=total_words)

# Build the model
model = Sequential()
model.add(Embedding(total_words, 10, input_length=max_sequence_len-1))
model.add(LSTM(50))
model.add(Dense(total_words, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(predictors, label, epochs=100, verbose=1)

# Function to generate text
def generate_text(seed_text, next_words, model, max_sequence_len):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted_probs = model.predict(token_list, verbose=0)[0]
        predicted_index = np.argmax(predicted_probs)
        
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted_index:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

# User input to generate text
user_input = input("Enter a starting phrase: ")
num_words = int(input("Enter number of words to generate: "))

generated_text = generate_text(user_input.lower(), num_words, model, max_sequence_len)
print("Generated Text:", generated_text)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0